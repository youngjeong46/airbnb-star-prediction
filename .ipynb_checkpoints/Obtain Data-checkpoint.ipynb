# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('listings.csv',delimiter=',',low_memory=False)

# %%
df_part=df[df.review_scores_rating>80]

# %%
sns.distplot(df_part.review_scores_rating)

# %%
df2 = pd.read_csv('reviews.csv',delimiter=',')

# %%
df3 = pd.read_csv('reviews2.csv',delimiter=',')

# %%
df2
# Out:
#         listing_id        date
# 0             2318  2008-09-15
# 1             2318  2017-01-10
# 2             2318  2017-04-01
# 3             2318  2017-04-25
# 4             2318  2017-06-18
# 5             2318  2017-07-09
# 6             2318  2017-07-24
# 7             2318  2017-09-21
# 8             2318  2017-11-06
# 9             2318  2017-11-20
# 10            2318  2017-12-27
# 11            2318  2018-02-20
# 12            2318  2018-02-25
# 13            2318  2018-03-28
# 14            2318  2018-04-04
# 15            2318  2018-04-22
# 16            2318  2018-06-05
# 17            2318  2018-06-11
# 18            2318  2018-06-25
# 19            2318  2018-09-18
# 20            2318  2018-11-24
# 21            4291  2013-07-01
# 22            4291  2013-07-08
# 23            4291  2013-07-14
# 24            4291  2013-08-03
# 25            4291  2013-08-06
# 26            4291  2013-08-10
# 27            4291  2013-08-13
# 28            4291  2013-08-30
# ...
